# %%
from env import my_setup
my_setup()
# Out:
# import os
# from pydataset import data
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import math as m
# from scipy import stats
# from env import gdb
# from env import Percent
# from env import output_chi2_contingency
# from sklearn.model_selection import train_test_split
# import acquire
# import prepare

# %%
import os
from pydataset import data
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math as m
from scipy import stats
from env import gdb
from env import Percent
from env import output_chi2_contingency
from sklearn.model_selection import train_test_split
import acquire
import prepare

# %% [markdown]
# # Exercises
#
# The end product of these exercise is a jupyter notebook (`classification_exercises.ipynb`) and an `acquire.py` file. The notebook will contain all your work as you move through the exercises. The `acquire.py` file should contain the final functions that acquire the data into a pandas dataframe.
#
# 1. Make a new repo called `classification-exercises` on both GitHub and within your `codeup-data-science` directory. This will be where you do your work for this module.
#
# 2. Inside of your local `classification-exercises` repo, create a file named `.gitignore` with the following contents:
#
#
#   * env.py
#   * .DS_Store
#   * .ipynb_checkpoints/
#   * __pycache__
#   * *.csv
# #### Add and commit your `.gitignore` file before moving forward.

# %% [markdown]
# 3. Now that you are 100% sure that your `.gitignore` file lists `env.py`, create or copy your `env.py` file inside of `classification-exercises`. Running git status should show that git is ignoring this file.

# %% [markdown]
# 4. In a jupyter notebook, `classification_exercises.ipynb`, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, `df_iris`, from this data.

# %%
df_iris = data('iris')
df_iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
#   - print the first 3 rows

# %%
# Our new way!
df_iris = acquire.get_iris_data()

# %%
print(df_iris[:3])
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
#   - print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
#   - print the column names

# %%
df_iris.columns.to_list()
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %% [markdown]
#   - print the data type of each column

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
#   - print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# 5. Read the data from this google sheet into a dataframe, df_google.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
csv_export_url

df_googlesheet = pd.read_csv(csv_export_url)
df_googlesheet.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
def read_googlesheet(sheet_url):
    '''
    This function takes in a `sheet_url` from a shared google sheet ;dtype= str
    and returns the sheet as a pd.DataFrame
    '''
#     First it uses .replace to change the google sheet url into a .csv export format
    csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
    
#     Then it uses pd.read_csv to read it into a DataFrame
    return pd.read_csv(csv_export_url)

# %%
df_train = read_googlesheet('https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
#   - print the first 3 rows

# %%
df_train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
#   - print the number of rows and columns

# %%
df_train.shape
# Out:
# (891, 12)

# %% [markdown]
#   - print the column names

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
#   - print the data type of each column

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
#   - print the summary statistics for each of the numeric variables

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
#   - print the unique values for each of your categorical variables

# %%
df_train.columns = df_train.columns.str.lower()

# %%
def object_columns_nunique(df):
    for col in df:
        if df[col].dtype == 'object':
            print(f'{col:>10} has {df[col].nunique():>4} unique values')

# %%
# col_len = 0
# val_len = 0

# for col in df_googlesheet:
#     if df_googlesheet[col].dtype == 'object':
#         if col_len < len(col): col_len = len(col)
#         if val_len < len(str(df_googlesheet[col].nunique())): val_len = len(str(df_googlesheet[col].nunique()))

for col in df_googlesheet:
    if df_googlesheet[col].dtype == 'object':
        print(f'{col:>10} has {df_googlesheet[col].nunique():>4} unique values')
# Out:
#       Name has  891 unique values
#        Sex has    2 unique values
#     Ticket has  681 unique values
#      Cabin has  147 unique values
#   Embarked has    3 unique values

# %%
df_train.sex.unique(), df_train.embarked.unique()
# Out:
# (array(['male', 'female'], dtype=object),
#  array(['S', 'C', 'Q', nan], dtype=object))

# %% [markdown]
# 6. Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
excel_exercises = pd.read_excel('excel_exercises.xlsx')

# %% [markdown]
#   - assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = excel_exercises.head(100)

# %% [markdown]
#   - print the number of rows of your original dataframe

# %%
len(excel_exercises)
# Out:
# 7049

# %% [markdown]
#   - print the first 5 column names

# %%
excel_exercises.columns[:5]
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %% [markdown]
#   - print the column names that have a data type of object

# %%
excel_exercises.select_dtypes(include=['object']).columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['customer_id', 'gender', 'partner', 'dependents', 'payment_type',
#        'churn'],
#       dtype='object')>

# %% [markdown]
#   - compute the range for each of the numeric variables.

# %%
excel_exercises.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges
# count      7049.000000    7038.000000
# mean         64.747014    2283.043883
# std          30.099460    2266.521984
# min          18.250000      18.800000
# 25%          35.450000     401.587500
# 50%          70.350000    1397.100000
# 75%          89.850000    3793.775000
# ...

# %% [markdown]
# ## Make a new python module, acquire.py to hold the following data aquisition functions:

# %%
# import acquire

# %% [markdown]
# 1. Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
acquire.get_titanic_data()
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %% [markdown]
# 2. Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.

# %%
acquire.get_iris_data()
# Out:
#      measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0                 1           5.1          3.5           1.4          0.2
# 1                 2           4.9          3.0           1.4          0.2
# 2                 3           4.7          3.2           1.3          0.2
# 3                 4           4.6          3.1           1.5          0.2
# 4                 5           5.0          3.6           1.4          0.2
# 5                 6           5.4          3.9           1.7          0.4
# 6                 7           4.6          3.4           1.4          0.3
# 7                 8           5.0          3.4           1.5          0.2
# 8                 9           4.4          2.9           1.4          0.2
# 9                10           4.9          3.1           1.5          0.1
# 10               11           5.4          3.7           1.5          0.2
# 11               12           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# 3. Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join all 4 tables together, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.

# %%
acquire.get_telco_data()
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines internet_service_type online_security  \
# ...

# %% [markdown]
# 4. Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %% [markdown]
# #### See Above

# %% [markdown]
# # Make sure your env.py and csv files are not being pushed to GitHub!

# %% [markdown]
# # Exercises
# The end product of this exercise should be the specified functions in a python script named `prepare.py`. Do these in your classification_exercises.ipynb first, then transfer to the `prepare.py` file.
#
# This work should all be saved in your `local classification-exercises` repo. Then add, commit, and push your changes.
#
# Using the Iris Data:

# %% [markdown]
# 1. Use the function defined in acquire.py to load the iris data.

# %%
df_iris = acquire.get_iris_data()
df_iris
# Out:
#      measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0                 1           5.1          3.5           1.4          0.2
# 1                 2           4.9          3.0           1.4          0.2
# 2                 3           4.7          3.2           1.3          0.2
# 3                 4           4.6          3.1           1.5          0.2
# 4                 5           5.0          3.6           1.4          0.2
# 5                 6           5.4          3.9           1.7          0.4
# 6                 7           4.6          3.4           1.4          0.3
# 7                 8           5.0          3.4           1.5          0.2
# 8                 9           4.4          2.9           1.4          0.2
# 9                10           4.9          3.1           1.5          0.1
# 10               11           5.4          3.7           1.5          0.2
# 11               12           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# 2. Drop the species_id and measurement_id columns.

# %%
df_iris.drop(columns=['measurement_id', 'species_id', 'species_id.1'], inplace=True)

# %% [markdown]
# 3. Rename the species_name column to just species.

# %%
df_iris.rename(columns = {'species_name':'species'}, inplace=True)

# %% [markdown]
# 4. Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %%
dummy_df = pd.get_dummies(df_iris.species, drop_first=True)

# %%
pd.concat([df_iris, dummy_df], axis=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# 5. Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris():
    df_iris = acquire.get_iris_data()
    df_iris.drop(columns=['measurement_id', 'species_id', 'species_id.1'], inplace=True)
    df_iris.rename(columns = {'species_name':'species'}, inplace=True)
    dummy_df = pd.get_dummies(df_iris.species, drop_first=True)
    return pd.concat([df_iris, dummy_df], axis=1)

# %%
prep_iris()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# # Using the Titanic dataset

# %% [markdown]
# 1. Use the function defined in acquire.py to load the Titanic data.

# %%
df = acquire.get_titanic_data()

# %%
df
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns.

# %%
df.drop(columns = ['class', 'embarked', 'deck', 'age'], inplace=True)

# %%
df
# Out:
#      passenger_id  survived  pclass     sex  sibsp  parch     fare  \
# 0               0         0       3    male      1      0   7.2500
# 1               1         1       1  female      1      0  71.2833
# 2               2         1       3  female      0      0   7.9250
# 3               3         1       1  female      1      0  53.1000
# 4               4         0       3    male      0      0   8.0500
# ..            ...       ...     ...     ...    ...    ...      ...
# 886           886         0       2    male      0      0  13.0000
# 887           887         1       1  female      0      0  30.0000
# 888           888         0       3  female      1      2  23.4500
# 889           889         1       1    male      0      0  30.0000
# 890           890         0       3    male      0      0   7.7500
#
#      embark_town  alone
# 0    Southampton      0
# 1      Cherbourg      0
# 2    Southampton      1
# 3    Southampton      0
# 4    Southampton      1
# ...

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummy_df = pd.get_dummies(df[['sex', 'embark_town']], drop_first=True)

# %%
df = pd.concat([df, dummy_df], axis=1)

# %%
df.drop(columns= ['sex', 'embark_town'], inplace=True)

# %% [markdown]
# 4. Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def prep_titanic():
    df = acquire.get_titanic_data()
    df.drop(columns = ['class', 'embarked', 'deck', 'age'], inplace=True)
    
    dummy_df = pd.get_dummies(df[['sex', 'embark_town']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    
    df.drop(columns= ['sex', 'embark_town'], inplace=True)
    return df

# %%
prep_titanic()
# Out:
#      passenger_id  survived  pclass  sibsp  parch     fare  alone  sex_male  \
# 0               0         0       3      1      0   7.2500      0         1
# 1               1         1       1      1      0  71.2833      0         0
# 2               2         1       3      0      0   7.9250      1         0
# 3               3         1       1      1      0  53.1000      0         0
# 4               4         0       3      0      0   8.0500      1         1
# ..            ...       ...     ...    ...    ...      ...    ...       ...
# 886           886         0       2      0      0  13.0000      1         1
# 887           887         1       1      0      0  30.0000      1         0
# 888           888         0       3      1      2  23.4500      0         0
# 889           889         1       1      0      0  30.0000      1         1
# 890           890         0       3      0      0   7.7500      1         1
#
#      embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# # Using the Telco dataset

# %%
df = acquire.get_telco_data()

# %% [markdown]
# 1. Use the function defined in acquire.py to load the Telco data.

# %%
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines internet_service_type online_security  \
# ...

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            7043 non-null   object
#  1   gender                 7043 non-null   object
#  2   senior_citizen         7043 non-null   int64
#  3   partner                7043 non-null   object
#  4   dependents             7043 non-null   object
#  5   tenure                 7043 non-null   int64
#  6   phone_service          7043 non-null   object
#  7   multiple_lines         7043 non-null   object
#  8   internet_service_type  7043 non-null   object
#  9   online_security        7043 non-null   object
#  10  online_backup          7043 non-null   object
#  11  device_protection      7043 non-null   object
#  12  tech_support           7043 non-null   object
#  13  streaming_tv           7043 non-null   object
# ...

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
# object_columns_nunique(df)
encode = ['gender', 'partner', 'dependents', 'phone_service', 'multiple_lines', 'internet_service_type', 
         'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
         'contract_type', 'paperless_billing', 'payment_type', 'churn']

# %%
df[encode]
# Out:
#       gender partner dependents phone_service    multiple_lines  \
# 0     Female     Yes        Yes           Yes                No
# 1       Male      No         No           Yes               Yes
# 2       Male      No         No           Yes                No
# 3       Male     Yes         No           Yes                No
# 4     Female     Yes         No           Yes                No
# ...      ...     ...        ...           ...               ...
# 7038  Female      No         No           Yes                No
# 7039    Male     Yes         No           Yes               Yes
# 7040    Male      No         No           Yes                No
# 7041    Male     Yes        Yes           Yes                No
# 7042    Male     Yes        Yes            No  No phone service
#
#      internet_service_type online_security online_backup device_protection  \
# 0                      DSL              No           Yes                No
# ...

# %%
df.total_charges.isnull().sum()
# Out:
# 0

# %%
# df['null_charges'] = pd.to_numeric(df['total_charges'], errors='coerce').isnull()
df['null_charges']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'null_charges'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_with_null_charges = df

# %%
df['total_charges'][df['null_charges'] == True] = df['monthly_charges']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'null_charges'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.total_charges = df.total_charges.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 df.total_charges = df.total_charges.astype(float)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            7043 non-null   object
#  1   gender                 7043 non-null   object
#  2   senior_citizen         7043 non-null   int64
#  3   partner                7043 non-null   object
#  4   dependents             7043 non-null   object
#  5   tenure                 7043 non-null   int64
#  6   phone_service          7043 non-null   object
#  7   multiple_lines         7043 non-null   object
#  8   internet_service_type  7043 non-null   object
#  9   online_security        7043 non-null   object
#  10  online_backup          7043 non-null   object
#  11  device_protection      7043 non-null   object
#  12  tech_support           7043 non-null   object
#  13  streaming_tv           7043 non-null   object
# ...

# %%
df.drop(columns= 'null_charges', inplace=True)

# %%
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines internet_service_type online_security  \
# ...

# %%
dummy_df = pd.get_dummies(df[encode], drop_first=True)
dummy_df.head()
# Out:
#    gender_Male  partner_Yes  dependents_Yes  phone_service_Yes  \
# 0            0            1               1                  1
# 1            1            0               0                  1
# 2            1            0               0                  1
# 3            1            1               0                  1
# 4            0            1               0                  1
#
#    multiple_lines_No phone service  multiple_lines_Yes  \
# 0                                0                   0
# 1                                0                   1
# 2                                0                   0
# 3                                0                   0
# 4                                0                   0
#
#    internet_service_type_Fiber optic  internet_service_type_None  \
# 0                                  0                           0
# 1                                  0                           0
# ...

# %%
df = pd.concat([df, dummy_df], axis=1)
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines internet_service_type online_security  \
# ...

# %%
df.drop(columns=encode)
# Out:
#      customer_id  senior_citizen  tenure  monthly_charges  total_charges  \
# 0     0002-ORFBO               0       9            65.60         593.30
# 1     0003-MKNFE               0       9            59.90         542.40
# 2     0004-TLHLJ               0       4            73.90         280.85
# 3     0011-IGKFF               1      13            98.00        1237.85
# 4     0013-EXCHZ               1       3            83.90         267.40
# ...          ...             ...     ...              ...            ...
# 7038  9987-LUTYD               0      13            55.15         742.90
# 7039  9992-RRAMN               0      22            85.10        1873.70
# 7040  9992-UJOEL               0       2            50.30          92.75
# 7041  9993-LHIEB               0      67            67.85        4627.65
# 7042  9995-HOTOH               0      63            59.00        3707.60
#
#       gender_Male  partner_Yes  dependents_Yes  phone_service_Yes  \
# ...

# %%
def prep_telco():
    df = acquire.get_telco_data()

    encode = ['gender', 'partner', 'dependents', 'phone_service', 'multiple_lines', 'internet_service_type', 
             'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
             'contract_type', 'paperless_billing', 'payment_type', 'churn']

    df['null_charges'] = pd.to_numeric(df['total_charges'], errors='coerce').isnull()

    df['total_charges'][df['null_charges']== True] = df['monthly_charges'][df['null_charges']== True]

    df.total_charges = df.total_charges.astype(float)

    df.drop(columns= 'null_charges', inplace=True)

    dummy_df = pd.get_dummies(df[encode], drop_first=True)

    df = pd.concat([df, dummy_df], axis=1)

    df = df.drop(columns=encode)
    print(df.info())
    return df

# %%
prep_telco()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customer_id                            7043 non-null   object
#  1   senior_citizen                         7043 non-null   int64
#  2   tenure                                 7043 non-null   int64
#  3   monthly_charges                        7043 non-null   float64
#  4   total_charges                          7043 non-null   float64
#  5   gender_Male                            7043 non-null   uint8
#  6   partner_Yes                            7043 non-null   uint8
#  7   dependents_Yes                         7043 non-null   uint8
#  8   phone_service_Yes                      7043 non-null   uint8
#  9   multiple_lines_No phone service        7043 non-null   uint8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customer_id                            7043 non-null   object
#  1   senior_citizen                         7043 non-null   int64
#  2   tenure                                 7043 non-null   int64
#  3   monthly_charges                        7043 non-null   float64
#  4   total_charges                          7043 non-null   float64
#  5   gender_Male                            7043 non-null   uint8
#  6   partner_Yes                            7043 non-null   uint8
#  7   dependents_Yes                         7043 non-null   uint8
#  8   phone_service_Yes                      7043 non-null   uint8
#  9   multiple_lines_No phone service        7043 non-null   uint8
# ...

# %% [markdown]
# 4. Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
# telco['gender_encode'] = telco.gender.map({'Female': 1, 'Male': 0})

# %% [markdown]
# # Exercises
# ## Part 1
# Continue in your `classification_exercises.ipynb` notebook. As always, add, commit, and push your changes.
#
# **Section 1 - iris_db:** Using iris data from our mySQL server and the methods used in the lesson above:

# %% [markdown]
# ### 1. Acquire, prepare & split your data.

# %%
iris_df = acquire.get_iris_data()

# %%
iris_df = prepare.prep_iris()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
#  5   versicolor    150 non-null    uint8
#  6   virginica     150 non-null    uint8
# dtypes: float64(4), object(1), uint8(2)
# memory usage: 6.3+ KB
# None

# %%
iris_train, iris_validate, iris_test = prepare.split_data(iris_df,'species')
# Out:
# Prepared df: (150, 7)
#
# Train: (90, 7)
# Validate: (30, 7)
# Test: (30, 7)

# %% [markdown]
# ### 2. Univariate Stats

# %%
iris_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 70            5.9          3.2           4.8          1.8  versicolor
# 123           6.3          2.7           4.9          1.8   virginica
# 87            6.3          2.3           4.4          1.3  versicolor
# 3             4.6          3.1           1.5          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
#
#      versicolor  virginica
# 70            1          0
# 123           0          1
# 87            1          0
# 3             0          0
# 15            0          0

# %% [markdown]
# #####  * For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).

# %%
num_var = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
sns.set_theme(style="whitegrid")
for col in num_var:
    print(iris_train[col].describe())
    fig, ax = plt.subplots(1,2, figsize=(12,3))
        
    sns.boxplot(data=iris_train,
                x=col, 
                meanline=True, 
                labels=[col], ax=ax[0]
               ).set(title=f'The Distribution of \
{col.split("_")[0].capitalize()} \
{col.split("_")[1].capitalize()} in cm')
#     ax[0].set_xticklabels(labels=f'{col.split("_")[0].capitalize()} {col.split("_")[1].capitalize()}')
    
    sns.histplot(data=iris_train, 
                 x=col, 
                 ax=ax[1]
                ).set(title=f'The Number of \
{col.split("_")[0].capitalize()}\'s \nWith \
{col.split("_")[1].capitalize()} X in cm\'s'
                     )
#     plt.ylabel()
    
    plt.show()
# Out:
# count    90.000000
# mean      5.875556
# std       0.792282
# min       4.400000
# 25%       5.225000
# 50%       5.800000
# 75%       6.400000
# max       7.900000
# Name: sepal_length, dtype: float64
# count    90.000000
# mean      3.070000
# std       0.436135
# min       2.200000
# 25%       2.800000
# 50%       3.000000
# 75%       3.375000
# max       4.400000
# Name: sepal_width, dtype: float64
# count    90.000000
# mean      3.782222
# std       1.742114
# min       1.200000
# 25%       1.600000
# 50%       4.250000
# 75%       5.100000
# max       6.900000
# Name: petal_length, dtype: float64
# count    90.000000
# mean      1.203333
# std       0.755422
# min       0.100000
# 25%       0.400000
# 50%       1.300000
# 75%       1.800000
# max       2.500000
# Name: petal_width, dtype: float64

# %%
cat_vars = ['versicolor', 'virginica', 'species']

# %% [markdown]
# #####  * For each species (categorical variable): create a frequency table and a bar plot of those frequencies.

# %%
for col in cat_vars:
    print(col)
    print(iris_train[col].value_counts())
    print(iris_train[col].value_counts(normalize=True)*100)
    sns.countplot(x=col, data=iris_train)
    plt.show()
# Out:
# versicolor
# 0    60
# 1    30
# Name: versicolor, dtype: int64
# 0    66.666667
# 1    33.333333
# Name: versicolor, dtype: float64
# virginica
# 0    60
# 1    30
# Name: virginica, dtype: int64
# 0    66.666667
# 1    33.333333
# Name: virginica, dtype: float64
# species
# versicolor    30
# virginica     30
# setosa        30
# Name: species, dtype: int64
# versicolor    33.333333
# virginica     33.333333
# setosa        33.333333
# Name: species, dtype: float64

# %% [markdown]
# #####  * Document takeaways & any actions.

# %% [markdown]
#   - **`Petals` have a much greater variance than `Sepals`**
#
#   - **There's an equal number of each species in each dataset**

# %% [markdown]
# ### 3. Bivariate Stats

# %%
# plt.title("Females are more likely to survive")
# sns.barplot(x='sex_male', y='survived', data=train)
# pop_survival_rate = train.survived.mean()
# plt.axhline(pop_survival_rate, label='population survival rate')
# plt.legend()
# plt.show()

# %% [markdown]
# #####  * Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).

# %%
data = iris_train

for col in num_var:
    name = f'{col.split("_")[0].capitalize()} {col.split("_")[1].capitalize()}'
    sns.barplot(y=col, 
                x='species', 
                data=data
               ).set(title=f'{name} in cm')
    average = iris_train[col].mean()
    plt.axhline(average, label=f'Average {name}')
    plt.legend()
    plt.show()

# %% [markdown]
# #####  * For each measurement type, compute the descriptive statistics for each species.

# %%
species_list = iris_train.species.unique().tolist()
species_list
# Out:
# ['versicolor', 'virginica', 'setosa']

# %%
def measurement_name():
    name = f"{col.split('_')[0].capitalize()} {col.split('_')[1].capitalize()}"
    return name

# %%
# name = f"{col.split('_')[0].capitalize()} {col.split('_')[1].capitalize()}"
# name = '{} {}'.format(col.split('_')[0].capitalize(), col.split('_')[1].capitalize())

# %%
for col in num_var:
    name = f"{col.split('_')[0].capitalize()} {col.split('_')[1].capitalize()}"
    for spec in species_list:
        output = iris_train[[col]][iris_train.species == spec].describe()
        print(f'The {spec} has a {name} statistical description')
        print(output)
# Out:
# The versicolor has a Sepal Length statistical description
#        sepal_length
# count      30.00000
# mean        5.91000
# std         0.47659
# min         4.90000
# 25%         5.60000
# 50%         5.80000
# 75%         6.17500
# max         7.00000
# The virginica has a Sepal Length statistical description
#        sepal_length
# count     30.000000
# mean       6.646667
# std        0.533520
# min        5.800000
# 25%        6.300000
# 50%        6.500000
# 75%        6.900000
# max        7.900000
# The setosa has a Sepal Length statistical description
#        sepal_length
# count     30.000000
# mean       5.070000
# std        0.356371
# min        4.400000
# 25%        4.825000
# 50%        5.000000
# 75%        5.375000
# max        5.800000
# The versicolor has a Sepal Width statistical description
#        sepal_width
# count    30.000000
# mean      2.806667
# std       0.281539
# min       2.300000
# 25%       2.625000
# 50%       2.800000
# 75%       3.000000
# ...

# %% [markdown]
# #####  * For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.

# %% [markdown]
#  **The following tests assume :**
#
#    **Hₒᴳ — (General Null Hypothesis): Measurement Distributions Are the Same Between Species**
#
#   - The Mann-Whitney U test is a nonparametric test of <br>the null hypothesis that the istribution underlying sample `x`<br> is the same as the distribution underlying sample `y`. <br>It is often used as a test of of difference in location between distributions.<br><br>
#   - Independent `populations` & `Not` normal distributions

# %%
def strike(text):
    result = ''
    for c in text:
        result = result + c + '\u0336'
    return result

# %%
α = .05
for col in num_var:
    name= measurement_name()
    x= iris_train[col][iris_train.species == 'virginica']
    y= iris_train[col][iris_train.species == 'versicolor']
    Hₒ = f'Hₒ: The {name} Distributions of Virginica and Versicolor are the same'
    
    U, p = stats.mannwhitneyu(x,y)
    print('________________________________________________________')
    print(f'\n\nThe {name} distributions of the Virginica to Versicolor')
    print(f'    Has a U-stat of {U} and p-value aprox. {Percent(p)}\n')
    if p < α:
        print(f'           We can REJECT the Hₒ:')
        print(strike(Hₒ+'\n'))
    else:
        print(f'           The Hₒ CANNOT be rejected:')
        print(Hₒ+'\n')
# Out:
# ________________________________________________________
#
#
# The Sepal Length distributions of the Virginica to Versicolor
#     Has a U-stat of 767.0 and p-value aprox. 0.00%
#
#            We can REJECT the Hₒ:
# H̶ₒ̶:̶ ̶T̶h̶e̶ ̶S̶e̶p̶a̶l̶ ̶L̶e̶n̶g̶t̶h̶ ̶D̶i̶s̶t̶r̶i̶b̶u̶t̶i̶o̶n̶s̶ ̶o̶f̶ ̶V̶i̶r̶g̶i̶n̶i̶c̶a̶ ̶a̶n̶d̶ ̶V̶e̶r̶s̶i̶c̶o̶l̶o̶r̶ ̶a̶r̶e̶ ̶t̶h̶e̶ ̶s̶a̶m̶e̶
# ̶
# ________________________________________________________
#
#
# The Sepal Width distributions of the Virginica to Versicolor
#     Has a U-stat of 575.0 and p-value aprox. 6.37%
#
#            The Hₒ CANNOT be rejected:
# Hₒ: The Sepal Width Distributions of Virginica and Versicolor are the same
#
# ________________________________________________________
#
#
# The Petal Length distributions of the Virginica to Versicolor
#     Has a U-stat of 892.5 and p-value aprox. 0.00%
#
#            We can REJECT the Hₒ:
# ...

# %% [markdown]
# #####  * Document takeaways & any actions.

# %% [markdown]
# ### The Hₒᴳ : ~~Measurement Distributions Are the Same Between Species~~<br>
#   - Was REJECTED on 3 out of 4 measurements<br>
#   - The `Sepal Width` distributions are the only measurement where we Cannot reject the Null<br>
#   - If we were looking at a `93% confidence` range,<br>   we could have rejected `Hₒᴳ` outright

# %% [markdown]
# ### 4. Multivariate Stats

# %% [markdown]
# #####  * Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
# for col in num_var:
#     iris_train[col]
# This is sooooo unnecessary!

# %%
sns.pairplot(data = iris_train,
             x_vars=num_var, 
             y_vars=num_var, 
             hue='species',
             corner=True
            )
plt.show()

# %% [markdown]
# ### As previously observed through statistical testing above:
#   - We see the distributions of each measurement when conrtroled for species<br> are distinctly different save the `Sepal Width` of the `Versicolor` and `Virginica`.
# <br><br>
# ### Additional observation:<br>
#   - The best looking separation of the training population<br>looks to be the Petal Length to Petal Width ratio.<br><br>
#   - The two most distinct separations of measurement distributions<br>are also between Petal Length and Petal Width.

# %% [markdown]
# #####  * Visualize two numeric variables by means of the species. Hint: sns.relplot with hue or col

# %%
sns.relplot(x = iris_train.petal_length, 
            y = iris_train.petal_width,
            hue = iris_train.species
           )

# %%
sns.jointplot(
data=iris_train,
x='petal_length',
y='petal_width',
hue = 'species',
kind='kde',
height = 8
)

# %% [markdown]
# #####  * Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
iris_melt = iris_train.drop(columns=['versicolor','virginica'])
iris_melt = pd.melt(iris_melt, 
                    id_vars='species', 
                    var_name='measured', 
                    value_name='centimeters'
                   )
iris_melt
# Out:
#         species      measured  centimeters
# 0    versicolor  sepal_length          5.9
# 1     virginica  sepal_length          6.3
# 2    versicolor  sepal_length          6.3
# 3        setosa  sepal_length          4.6
# 4        setosa  sepal_length          5.7
# ..          ...           ...          ...
# 355      setosa   petal_width          0.2
# 356      setosa   petal_width          0.2
# 357  versicolor   petal_width          1.3
# 358      setosa   petal_width          0.4
# 359  versicolor   petal_width          1.3
#
# [360 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.swarmplot(data = iris_melt,
              x = 'measured',
              y = 'centimeters',
              hue = 'species',
              size=4,
              ax=ax
             )
# Out:
# <AxesSubplot:xlabel='measured', ylabel='centimeters'>

# %%
# x1= iris_train.petal_length
# y1= iris_train.petal_width
# z1= iris_train

# axes = plt.axes(projection='3d')
# axes.plot_wireframe(x1,y1,z1)
# plt.show()

# %% [markdown]
# #####  * Ask a specific question of the data, such as: is the sepal area signficantly different in virginica compared to setosa? Answer the question through both a plot and using a mann-whitney or t-test. If you use a t-test, be sure assumptions are met (independence, normality, equal variance).

# %% [markdown]
# ### Is the sepal area signifcatly different between virginica and versicolor?

# %%
iris_train['sepal_area'] = iris_train.sepal_length * iris_train.sepal_width

# %%
iris_train.sepal_area[iris_train.species == 'virginica'].describe()
# Out:
# count    30.000000
# mean     19.722667
# std       3.177243
# min      13.200000
# 25%      17.655000
# 50%      19.930000
# 75%      21.075000
# max      30.020000
# Name: sepal_area, dtype: float64

# %%
iris_train.sepal_area[iris_train.species == 'versicolor'].describe()
# Out:
# count    30.00000
# mean     16.65100
# std       2.60784
# min      11.76000
# 25%      14.88500
# 50%      16.36500
# 75%      18.27500
# max      22.40000
# Name: sepal_area, dtype: float64

# %%
iris_train.sepal_area[iris_train.species == 'virginica'].var()
# Out:
# 10.094875402298852

# %%
vir = iris_train.sepal_area[iris_train.species == 'virginica']

# %%
iris_train.sepal_area[iris_train.species == 'versicolor'].var()
# Out:
# 6.800830000000002

# %%
ver = iris_train.sepal_area[iris_train.species == 'versicolor']

# %%
col = 'sepal_area'
name= measurement_name()
x= vir
y= ver
Hₒ = f'Hₒ: The {name} Distributions of Virginica and Versicolor are the same'
    
U, p = stats.mannwhitneyu(x,y)
print('________________________________________________________')
print(f'\n\nThe {name} distributions of the Virginica to Versicolor')
print(f'    Has a U-stat of {U} and p-value aprox. {Percent(p)}\n')
if p < α:
    print(f'           We can REJECT the Hₒ:')
    print(strike(Hₒ+'\n'))
else:
    print(f'           The Hₒ CANNOT be rejected:')
    print(Hₒ+'\n')
# Out:
# ________________________________________________________
#
#
# The Sepal Area distributions of the Virginica to Versicolor
#     Has a U-stat of 701.5 and p-value aprox. 0.02%
#
#            We can REJECT the Hₒ:
# H̶ₒ̶:̶ ̶T̶h̶e̶ ̶S̶e̶p̶a̶l̶ ̶A̶r̶e̶a̶ ̶D̶i̶s̶t̶r̶i̶b̶u̶t̶i̶o̶n̶s̶ ̶o̶f̶ ̶V̶i̶r̶g̶i̶n̶i̶c̶a̶ ̶a̶n̶d̶ ̶V̶e̶r̶s̶i̶c̶o̶l̶o̶r̶ ̶a̶r̶e̶ ̶t̶h̶e̶ ̶s̶a̶m̶e̶
# ̶

# %%
sns.boxplot(data = iris_train,
            x = 'species',
            y = 'sepal_area'
           )
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_area'>

# %%
iris_train['petal_area'] = iris_train.petal_length * iris_train.petal_width

# %%
sns.jointplot(
data = iris_train,
    x= 'sepal_area',
    y= 'petal_area',
    hue= 'species',
    kind='kde',
    height=8
)

# %% [markdown]
# #####  * Document takeaways and any actions.

# %% [markdown]
# The `Sepal Area` distributions of the `Virginica` to `Versicolor`<br>
#
# &emsp;&emsp;Has a U-stat of `701.5` and p-value aprox. `0.02%`
#
#       With 99.8% confidence we can REJECT the Hₒ:
# H̶ₒ̶:̶ ̶T̶h̶e̶ ̶S̶e̶p̶a̶l̶ ̶A̶r̶e̶a̶ ̶D̶i̶s̶t̶r̶i̶b̶u̶t̶i̶o̶n̶s̶ ̶o̶f̶ ̶V̶i̶r̶g̶i̶n̶i̶c̶a̶ ̶a̶n̶d̶ ̶V̶e̶r̶s̶i̶c̶o̶l̶o̶r̶ ̶a̶r̶e̶ ̶t̶h̶e̶ ̶s̶a̶m̶e̶
# ̶

# %% [markdown]
# # Part II

# %%
df = acquire.get_titanic_data()
df = prepare.prep_titanic()
train, validate, test = prepare.split_data(df,'survived')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   passenger_id             891 non-null    int64
#  1   survived                 891 non-null    int64
#  2   pclass                   891 non-null    int64
#  3   sibsp                    891 non-null    int64
#  4   parch                    891 non-null    int64
#  5   fare                     891 non-null    float64
#  6   alone                    891 non-null    int64
#  7   sex_male                 891 non-null    uint8
#  8   embark_town_Queenstown   891 non-null    uint8
#  9   embark_town_Southampton  891 non-null    uint8
# dtypes: float64(1), int64(6), uint8(3)
# memory usage: 51.5 KB
# None
# Prepared df: (891, 10)
#
# Train: (534, 10)
# Validate: (178, 10)
# Test: (179, 10)

# %%
train.describe()
# Out:
#        passenger_id    survived      pclass       sibsp       parch  \
# count    534.000000  534.000000  534.000000  534.000000  534.000000
# mean     446.677903    0.383895    2.323970    0.514981    0.352060
# std      257.471048    0.486789    0.822928    1.143856    0.759941
# min        0.000000    0.000000    1.000000    0.000000    0.000000
# 25%      219.500000    0.000000    2.000000    0.000000    0.000000
# 50%      452.500000    0.000000    3.000000    0.000000    0.000000
# 75%      672.750000    1.000000    3.000000    1.000000    0.000000
# max      890.000000    1.000000    3.000000    8.000000    5.000000
#
#              fare       alone    sex_male  embark_town_Queenstown  \
# count  534.000000  534.000000  534.000000              534.000000
# mean    31.058106    0.627341    0.651685                0.086142
# std     46.866121    0.483966    0.476883                0.280837
# min      0.000000    0.000000    0.000000                0.000000
# ...

# %% [markdown]
# ## My first observation is that pclass should be categorical

# %% [markdown]
# #####  * Explore your `titanic` dataset more completely.

# %%
num_var = ['fare']

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

sns.boxplot(data = train,
            x= 'fare',
            meanline=True,
            ax=ax[0]
           ).set(title='The Distribution of Fare Price')

sns.histplot(data=train,
             x='fare',
             ax=ax[1]
            ).set(title='The number of Fares in each price range')
plt.show()

# %%
cat_vars = ['survived', 'pclass', 'sex_male', 'sibsp', 'parch', 'alone',
            'embark_town_Queenstown', 'embark_town_Southampton'
           ]

# %%
for col in cat_vars:
    print(col)
    print(train[col].value_counts())
    print(train[col].value_counts(normalize=True))
    sns.countplot(x=col, data=train)
    plt.show()
# Out:
# survived
# 0    329
# 1    205
# Name: survived, dtype: int64
# 0    0.616105
# 1    0.383895
# Name: survived, dtype: float64
# pclass
# 3    295
# 1    122
# 2    117
# Name: pclass, dtype: int64
# 3    0.552434
# 1    0.228464
# 2    0.219101
# Name: pclass, dtype: float64
# sex_male
# 1    348
# 0    186
# Name: sex_male, dtype: int64
# 1    0.651685
# 0    0.348315
# Name: sex_male, dtype: float64
# sibsp
# 0    378
# 1    106
# 2     22
# 3     10
# 4     10
# 8      5
# 5      3
# Name: sibsp, dtype: int64
# 0    0.707865
# 1    0.198502
# 2    0.041199
# 3    0.018727
# 4    0.018727
# 8    0.009363
# 5    0.005618
# Name: sibsp, dtype: float64
# parch
# 0    414
# 1     67
# 2     45
# 3      4
# 5      3
# 4      1
# Name: parch, dtype: int64
# 0    0.775281
# 1    0.125468
# 2    0.084270
# 3    0.007491
# 5    0.005618
# 4    0.001873
# Name: parch, dtype: float64
# alone
# 1    335
# 0    199
# Name: alone, dtype: int64
# 1    0.627341
# 0    0.372659
# ...

# %%
# sns.set(rc={"figure.figsize":(8, 4)})

sns.barplot(x='pclass', 
            y='survived', 
            data=train    
           )
pop_survival_rate = train.survived.mean()
plt.axhline(pop_survival_rate, label='poulation survival rate')
plt.legend()
plt.title('3rd class had the most people and least survivors')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [303], in <cell line: 10>()
#       8 plt.axhline(pop_survival_rate, label='poulation survival rate')
#       9 plt.legend()
# ---> 10 plt.title('3rd class had the most people and least survivors')
#      11 plt.show()
#
# TypeError: 'str' object is not callable

# %%
α = .05
Hₒ = 'survival and class are independant'
Hₐ = 'there is a relationship between class and survival'

observed = pd.crosstab(train.survived, train.pclass)

p = output_chi2_contingency(observed)

if p < α:
    print('REJECT Hₒ:', Hₒ)
# Out:
# Observed
# [[ 46  60 223]
#  [ 76  57  72]]
#
# Expected
# [[ 75  72 181]
#  [ 46  44 113]]
#
# ----
# chi^2 = 59.1404
# p     = 0.0000
# degf  = 2.0000
# REJECT Hₒ: survival and class are independant

# %%
def cat_vis(train, col):
#     plt.title(f'Relationship of survival rate and {col}')
    sns.barplot(x=col, y= 'survived', data=train).set(title= f'Relationship of survival rate and {col}')
    survival_rate = train.survived.mean()
    plt.axhline(survival_rate, label='survival rate')
    plt.legend()
    plt.show()
    
def cat_test(train,col):
    α = .05
    null_hyp = col+' and survival are independent'
    alt_hyp = 'Survival and '+col+' are related'
    observed = pd.crosstab(train.survived, train[col])
    p = output_chi2_contingency(observed)
    if p < α:
        print('We reject the null hypothesis that '+null_hyp)
        print(alt_hyp)
    else:
        print('We cannot reject the null hypothesis that '+null_hyp)
        
def cat_anal(train, col):
    cat_vis(train, col)
    cat_test(train, col)

# %%
for col in cat_vars:
    cat_anal(train, col)
# Out:
# Observed
# [[329   0]
#  [  0 205]]
#
# Expected
# [[202 126]
#  [126  78]]
#
# ----
# chi^2 = 529.7804
# p     = 0.0000
# degf  = 1.0000
# We reject the null hypothesis that survived and survival are independent
# Survival and survived are related
# Observed
# [[ 46  60 223]
#  [ 76  57  72]]
#
# Expected
# [[ 75  72 181]
#  [ 46  44 113]]
#
# ----
# chi^2 = 59.1404
# p     = 0.0000
# degf  = 2.0000
# We reject the null hypothesis that pclass and survival are independent
# Survival and pclass are related
# Observed
# [[ 46 283]
#  [140  65]]
#
# Expected
# [[114 214]
#  [ 71 133]]
#
# ----
# chi^2 = 161.7405
# p     = 0.0000
# degf  = 1.0000
# We reject the null hypothesis that sex_male and survival are independent
# Survival and sex_male are related
# Observed
# [[247  46  11   9   8   3   5]
#  [131  60  11   1   2   0   0]]
#
# Expected
# [[232  65  13   6   6   1   3]
#  [145  40   8   3   3   1   1]]
#
# ----
# chi^2 = 28.1720
# p     = 0.0001
# degf  = 6.0000
# ...

# %% [markdown]
# #####  * Determine drivers of the target variable

# %% [markdown]
# ### The relationship between Queenstown and Survival may be confounding
#   - If we find that Queenstown embarkees also paid lower fares,<br>maybe just use fare

# %%
train
# Out:
#      passenger_id  survived  pclass  sibsp  parch      fare  alone  sex_male  \
# 455           455         1       3      0      0    7.8958      1         1
# 380           380         1       1      0      0  227.5250      1         0
# 492           492         0       1      0      0   30.5000      1         1
# 55             55         1       1      0      0   35.5000      1         1
# 243           243         0       3      0      0    7.1250      1         1
# ..            ...       ...     ...    ...    ...       ...    ...       ...
# 695           695         0       2      0      0   13.5000      1         1
# 128           128         1       3      1      1   22.3583      0         0
# 636           636         0       3      0      0    7.9250      1         1
# 222           222         0       3      0      0    8.0500      1         1
# 496           496         1       1      1      0   78.2667      0         0
#
# ...

# %%
train['companions'] = train.sibsp + train.parch
# let's add our new train.companions back into our cat vars and rerun the analysis
cat_vars + ['companions']#... also, lets drop the embark info entirely 
# and start to think about companions as discrete a numeric field
# Out:
# ['survived',
#  'pclass',
#  'sex_male',
#  'sibsp',
#  'parch',
#  'alone',
#  'embark_town_Queenstown',
#  'embark_town_Southampton',
#  'companions']

# %%
cat_vars = cat_vars + ['companions']

# %%
cat_vars.remove('embark_town_Queenstown')
cat_vars.remove('embark_town_Southampton')

# %%
# Out:
# ['survived', 'pclass', 'sex_male', 'sibsp', 'parch', 'alone', 'companions']

# %%
for col in cat_vars:
    cat_anal(train, col)
# Out:
# Observed
# [[329   0]
#  [  0 205]]
#
# Expected
# [[202 126]
#  [126  78]]
#
# ----
# chi^2 = 529.7804
# p     = 0.0000
# degf  = 1.0000
# We reject the null hypothesis that survived and survival are independent
# Survival and survived are related
# Observed
# [[ 46  60 223]
#  [ 76  57  72]]
#
# Expected
# [[ 75  72 181]
#  [ 46  44 113]]
#
# ----
# chi^2 = 59.1404
# p     = 0.0000
# degf  = 2.0000
# We reject the null hypothesis that pclass and survival are independent
# Survival and pclass are related
# Observed
# [[ 46 283]
#  [140  65]]
#
# Expected
# [[114 214]
#  [ 71 133]]
#
# ----
# chi^2 = 161.7405
# p     = 0.0000
# degf  = 1.0000
# We reject the null hypothesis that sex_male and survival are independent
# Survival and sex_male are related
# Observed
# [[247  46  11   9   8   3   5]
#  [131  60  11   1   2   0   0]]
#
# Expected
# [[232  65  13   6   6   1   3]
#  [145  40   8   3   3   1   1]]
#
# ----
# chi^2 = 28.1720
# p     = 0.0001
# degf  = 6.0000
# ...

# %% [markdown]
# #####  * Determine if certain columns should be dropped

# %% [markdown]
# #####  * Determine if it would be valuable to bin some numeric columns

# %% [markdown]
# #####  * Determine if it would be valuable to combine multiple columns into one.

# %% [markdown]
# #####  * Does it make sense to combine any features?

# %% [markdown]
# #####  * Do you find any surprises?

# %% [markdown]
# #####  * Document any and all findings and takeaways in your notebook using markdown.

# %% [markdown]
# # Part III

# %%
df = acquire.get_telco_data()
df = prepare.prep_telco()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customer_id                            7043 non-null   object
#  1   senior_citizen                         7043 non-null   int64
#  2   tenure                                 7043 non-null   int64
#  3   monthly_charges                        7043 non-null   float64
#  4   total_charges                          7043 non-null   float64
#  5   gender_Male                            7043 non-null   uint8
#  6   partner_Yes                            7043 non-null   uint8
#  7   dependents_Yes                         7043 non-null   uint8
#  8   phone_service_Yes                      7043 non-null   uint8
#  9   multiple_lines_No phone service        7043 non-null   uint8
# ...

# %%
train, validate, test = prepare.split_data(df, 'churn_Yes')
# Out:
# Prepared df: (7043, 32)
#
# Train: (4225, 32)
# Validate: (1409, 32)
# Test: (1409, 32)

# %%
train.describe()
# Out:
#        senior_citizen       tenure  monthly_charges  total_charges  \
# count     4225.000000  4225.000000      4225.000000    4225.000000
# mean         0.161893    32.500828        65.056142    2298.609337
# std          0.368397    24.532563        30.268493    2271.507595
# min          0.000000     0.000000        18.250000      18.850000
# 25%          0.000000     9.000000        35.650000     411.600000
# 50%          0.000000    29.000000        70.400000    1401.150000
# 75%          0.000000    55.000000        90.150000    3865.450000
# max          1.000000    72.000000       118.750000    8672.450000
#
#        gender_Male  partner_Yes  dependents_Yes  phone_service_Yes  \
# count  4225.000000  4225.000000     4225.000000        4225.000000
# mean      0.508639     0.488521        0.306272           0.906982
# std       0.499985     0.499927        0.460999           0.290492
# min       0.000000     0.000000        0.000000           0.000000
# ...

# %%
num_vars = ['tenure', 'monthly_charges', 'total_charges']

# %%
cat_vars = train.columns.to_list()

# %%
type(cat_vars)
# Out:
# list

# %%
cat_vars

# %%
for i in num_vars:
    print(i)
    cat_vars.remove(i)
#     print(cat_vars)
cat_vars
# This doesn't work, and gives the: 
# AttributeError: 'NoneType' object has no attribute 'remove'
# Out:
# tenure
# monthly_charges
# total_charges
# ['customer_id',
#  'senior_citizen',
#  'gender_Male',
#  'partner_Yes',
#  'dependents_Yes',
#  'phone_service_Yes',
#  'multiple_lines_No phone service',
#  'multiple_lines_Yes',
#  'internet_service_type_Fiber optic',
#  'internet_service_type_None',
#  'online_security_No internet service',
#  'online_security_Yes',
#  'online_backup_No internet service',
#  'online_backup_Yes',
#  'device_protection_No internet service',
#  'device_protection_Yes',
#  'tech_support_No internet service',
#  'tech_support_Yes',
#  'streaming_tv_No internet service',
#  'streaming_tv_Yes',
#  'streaming_movies_No internet service',
#  'streaming_movies_Yes',
#  'contract_type_One year',
#  'contract_type_Two year',
#  'paperless_billing_Yes',
#  'payment_type_Credit card (automatic)',
#  'payment_type_Electronic check',
#  'payment_type_Mailed check',
#  'churn_Yes']

# %%
len(cat_vars)
# Out:
# 29

# %%
cat_vars.remove('tenure')

# cat_vars.remove('monthly_charges')
# cat_vars.remove('total_charges')
# len(cat_vars)

# %%
cat_vars.remove('customer_id')

# %%
cat_vars
# Out:
# ['senior_citizen',
#  'gender_Male',
#  'partner_Yes',
#  'dependents_Yes',
#  'phone_service_Yes',
#  'multiple_lines_No phone service',
#  'multiple_lines_Yes',
#  'internet_service_type_Fiber optic',
#  'internet_service_type_None',
#  'online_security_No internet service',
#  'online_security_Yes',
#  'online_backup_No internet service',
#  'online_backup_Yes',
#  'device_protection_No internet service',
#  'device_protection_Yes',
#  'tech_support_No internet service',
#  'tech_support_Yes',
#  'streaming_tv_No internet service',
#  'streaming_tv_Yes',
#  'streaming_movies_No internet service',
#  'streaming_movies_Yes',
#  'contract_type_One year',
#  'contract_type_Two year',
#  'paperless_billing_Yes',
#  'payment_type_Credit card (automatic)',
#  'payment_type_Electronic check',
#  'payment_type_Mailed check',
#  'churn_Yes']

# %%
# name = f'{col.split("_")[0].capitalize()} {col.split("_")[1].capitalize()}'

# %%
for col in num_vars:
    print(train[col].describe())
    fig, ax = plt.subplots(1,2, figsize=(12,3))
    
#     name = f'{col.split("_")[0].capitalize()} {col.split("_")[1].capitalize()}'
    
    sns.boxplot(data=train,
                x=col, 
                meanline=True, 
                labels=[col], ax=ax[0]
               ).set(title=f'The Distribution of {col} ')
#     ax[0].set_xticklabels(labels=f'{col.split("_")[0].capitalize()} {col.split("_")[1].capitalize()}')
    
    sns.histplot(data=train, 
                 x=col, 
                 ax=ax[1]
                ).set(title=f'The Number of Customers in each range'
                     )
#     plt.ylabel()
    
    plt.show()
# Out:
# count    4225.000000
# mean       32.500828
# std        24.532563
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64
# count    4225.000000
# mean       65.056142
# std        30.268493
# min        18.250000
# 25%        35.650000
# 50%        70.400000
# 75%        90.150000
# max       118.750000
# Name: monthly_charges, dtype: float64
# count    4225.000000
# mean     2298.609337
# std      2271.507595
# min        18.850000
# 25%       411.600000
# 50%      1401.150000
# 75%      3865.450000
# max      8672.450000
# Name: total_charges, dtype: float64

# %% [markdown]
#   - The distribution of tenure is super heavy on longest and shortest tenure
#   - The monthly charges have a huge spike at the lowest with a more normal curve
#     - From looking at this data previously:<br>we know that controling for:<br>- internet type and<br> -phone service<br> divides this up nicely
#   - The total charges makes sense skewing hard right,
#     - This shows that the largest group has the lowest charges...
#     - Some of this is from new cutomers, but
#       - This distribution is also affected by the <br>large number of people with low monthly charges

# %%
for col in cat_vars:
    print(col)
    print(train[col].value_counts())
    print(train[col].value_counts(normalize=True)*100)
    sns.countplot(x=col, data=train)
    plt.show()
# Out:
# senior_citizen
# 0    3541
# 1     684
# Name: senior_citizen, dtype: int64
# 0    83.810651
# 1    16.189349
# Name: senior_citizen, dtype: float64
# gender_Male
# 1    2149
# 0    2076
# Name: gender_Male, dtype: int64
# 1    50.863905
# 0    49.136095
# Name: gender_Male, dtype: float64
# partner_Yes
# 0    2161
# 1    2064
# Name: partner_Yes, dtype: int64
# 0    51.147929
# 1    48.852071
# Name: partner_Yes, dtype: float64
# dependents_Yes
# 0    2931
# 1    1294
# Name: dependents_Yes, dtype: int64
# 0    69.372781
# 1    30.627219
# Name: dependents_Yes, dtype: float64
# phone_service_Yes
# 1    3832
# 0     393
# Name: phone_service_Yes, dtype: int64
# 1    90.698225
# 0     9.301775
# Name: phone_service_Yes, dtype: float64
# multiple_lines_No phone service
# 0    3832
# 1     393
# Name: multiple_lines_No phone service, dtype: int64
# 0    90.698225
# 1     9.301775
# Name: multiple_lines_No phone service, dtype: float64
# multiple_lines_Yes
# 0    2418
# 1    1807
# ...

# %% [markdown]
# ### Observations:
#   **- senior_citizen:**
#   - Only `16%` of customers are senior citizens, `84%` not<br>
#
# **- gender_male:**
#   - The customers are split evenly (49%-51%) F/M<br>
#
# **- partner_Yes:**
#   - Similarly split (49% Yes, 51% No)<br>
#
# **- dependents_Yes:**
#   - Only about 31% Yes have dependents and 69% No do not<br>
#
# **- phone_service_Yes:**
#   - Nearly 91% of customers have phone service
#     - The 9% that Do not have phone service, are ALL DSL customers(from previous examination)<br>
#
# **- multiple_lines_ No phone service:**
#   - Shows the exact same split as phone_service_Yes
#     - This is the same information about the DSL customers
#     - DROPPED!
#
# **- multiple_lines_Yes:**
#   - nearly 43% Yes have multiple lines, while 57% No do not
#
# **- internet_service_type_Fiber optic:**
#   - 44% of customers have Fiber optic 56% do not
#     - This may be a similar and metric to the multiple lines,<br>but we'll have to look at that later
#
# **- internet_service_type_No Internet Service:**
#   - This is the almost 22% of customers that have no internet service
#     - The inference here is that about 34% of customers have DSL
#       - Further, we can safely say that about 26% of DSL customers <br>do Not have phone service (9/34 is .26)
#
# **- online_security_No Internet Service:**
#   - This looks like 22% of phone only customers have security, 78% do not
#
# **- onine_security_Yes:**
#   - Of all customers in the training set about 29% have online security
#     - this is only slightly greater than the No Interent customers
#
# **- online_backup_No Internet Service:**
#   - This is simarly about 22%
#     - This may be confounding with online security NIS,
#       - We could possibly drop, if that is so
#       - alternately we could add these together to make a new numeric field...
#
# **- online_backup_Yes:**
#   - For all customers there is a 35% showing that <br>people with internet have a greater adoption of online_backup
#
# **- device_protection_No Internet Service:-
#   - Matches online_security_NIS, and online_backup_NIS
#     - Seems likely these are the same 923 customers
#       - It might be worth breaking these out as a separate population...
#       - alternately, these otherwise confounding features, might be <br>combined into the aforementioned numerical feature
#
# **- device_protection_Yes:**
#   - Here we see a similar 35% overall sugesting that <br>most with device_protection also have online_backup
#     - 1483 here and 1479 in online_backup<br>
#
# **- tech_support_No Internet Service:**
#   - 22% or 923 people have it again...
#     - Further support for the drop or combine idea...
#
# **- tech_support_Yes:**
#   - Overall tech support again is nearly 29%
#     - Is this saying that only about 7% of these people (1223 - 923 = 300)<br>are internet customers...
#       - This is interesting and should be looked into further
#
# **- streaming_tv_No Internet Service:**
#   - The same 923 people again (it looks like, this should be confirmed with further analysis)
#
# **- streaming_tv_Yes:**
#   - a little over 39% (1657 people) 734 of whom are internet customers...
#     - I wonder if they're DSL, Fiber optic, or a mix
#
# **- streaming_movies_No Internet Service:**
#   - Again 923 people, (something needs to be done about this)
#
# **- streaming_movies_Yes:**
#   - 1671 people, almost 40%
#     - This again looks like some minor varience in the DSL/Fiber optic community
#
# **- contract_type_One Year:**
#   - 913 people, I wonder if these are all from the 923^population...?
#     - Also, should look at how many of these are still under 12 months
#       - If they are then they haven't had the opportunity to churn yet
#       - **Should we** separate or not look at people who haven't had the opp to churn...??
#
# **- contract_type_Two Year:**
#   - 955 people, almost 25% this is another place to look at their tenure
#     - Have they had the opportunity to churn?
#
# **- paperless_billing_Yes:**
#   - Nearly 60%... Need to think about/examine how this might relate to anything
#
# **- payment_type_Credit Card (automatic):**
#   - Nearly 22% with a total of 919 people
#     - Should definitely look into further relationships
#
# **- payment_type_Electronic check:**
#   - Nearly 34% which is 1423 people
#   - How does that work... who are these people???
#
# **- churn_Yes:**
#   - 1121 people Churned... this is what we really care about
#     - That's 26.53% of the entire training data set
#       - We still have no idea how many of the people <br>in the entire set have had the opportunity to churn
#       - Let's figure out the signifigance!!
#
# ## We may need to reaquire our data and control for ability to churn

# %%
9/34
# Out:
# 0.2647058823529412

# %%
data = train

for col in num_vars:
#     name = f'{col.split("_")[0].capitalize()} {col.split("_")[1].capitalize()}'
    sns.violinplot(y=col, 
                x='churn_Yes', 
                data=data
               ).set(title=f'{col} as related to Churn')
    average = train[col].mean()
    plt.axhline(average, label=f'Average {col}')
    plt.legend()
    plt.show()
    mask0 = train['churn_Yes'] == 0
    mask1 = train['churn_Yes'] == 1
    print(f'No Churn \n{train.loc[mask0, col].describe()},\n\nChurned \n{train.loc[mask1, col].describe()}')
# Out:
# No Churn
# count    3104.000000
# mean       37.635631
# std        24.106628
# min         0.000000
# 25%        15.000000
# 50%        38.000000
# 75%        61.000000
# max        72.000000
# Name: tenure, dtype: float64,
#
# Churned
# count    1121.000000
# mean       18.282783
# std        19.605515
# min         1.000000
# 25%         2.000000
# 50%        10.000000
# 75%        30.000000
# max        72.000000
# Name: tenure, dtype: float64
# No Churn
# count    3104.000000
# mean       61.628334
# std        31.227970
# min        18.250000
# 25%        25.100000
# 50%        64.950000
# 75%        88.850000
# max       118.750000
# Name: monthly_charges, dtype: float64,
#
# Churned
# count    1121.000000
# mean       74.547591
# std        25.115610
# min        18.850000
# 25%        56.500000
# 50%        79.700000
# 75%        94.700000
# max       118.350000
# Name: monthly_charges, dtype: float64
# No Churn
# count    3104.000000
# mean     2560.894894
# ...

# %% [markdown]
# ## Takeaways...<br>
# **- Tenure as related to Churn:**
#   - The tenure of those who churn sits at a mean of about `18 months`
#     - With mean of `18` but a median of `10 months`, most of the churners<br>
#       churn in **under a year**, a full `25%` within `2 months`<br>
#         - This leads me to think the people without an opp to churn<br>are even more important to control for
#
# **- Monthly charges as related to Churn:**
#   - Again we see the evidence of the different populations and need to add control
#     - A large group of the No-Churn set is in that low charge bump
#   - Additionally, we see that the largest amount of churn is in the mid upper range
#     - When controling against NIS it looks like this will be true of non_churners also...
#   - While monthly charges show a difference—<br>slightly higher for churners—this doesn't look like the biggest indicator
#
# **- Total charges as related to Churn:**
#   - While again there's a difference...
#     - We still need to control for NIS
#     - additionally the total charges mean and median are lower for the churn group
#       - It looks like churn predicts total charges more than the other way around
#       - **Maybe there's a way to transform this feature...**
#         - Are total_charges / tenure == or != to monthly charges...?
#           - If `t_c/tenure > m_c` then the monthly charges have been `reduced over time`
#           - If `t_c/tenure < m_c` then the monyhly charges have gone `up over time`

# %% [markdown]
# # Let's see if the MannWhitneyU test shows anything about<br>The groups of charges and tenure<br> Are they similar or different between churners or not?
#
# ### Hₒᴳ : The Numeric Feature Distributions of Non_Churners to Churners are the same

# %%
α = .05
for col in num_vars:
#     name= measurement_name()
    x= train[col][train['churn_Yes'] == 0]
    y= train[col][train['churn_Yes'] == 1]
    Hₒ = f'Hₒ: The {col} Distributions of Non_Churn and Churn are the same'
    
    U, p = stats.mannwhitneyu(x,y)
    print('________________________________________________________')
    print(f'\n\nThe {col} distributions of the Non_Churn to Churn')
    print(f'    Has a U-stat of {U} and p-value aprox. {Percent(p)}\n')
    if p < α:
        print(f'           We can REJECT the Hₒ:')
        print(strike(Hₒ+'\n'))
    else:
        print(f'           The Hₒ CANNOT be rejected:')
        print(Hₒ+'\n')
# Out:
# ________________________________________________________
#
#
# The tenure distributions of the Non_Churn to Churn
#     Has a U-stat of 2568403.5 and p-value aprox. 0.00%
#
#            We can REJECT the Hₒ:
# H̶ₒ̶:̶ ̶T̶h̶e̶ ̶t̶e̶n̶u̶r̶e̶ ̶D̶i̶s̶t̶r̶i̶b̶u̶t̶i̶o̶n̶s̶ ̶o̶f̶ ̶N̶o̶n̶_̶C̶h̶u̶r̶n̶ ̶a̶n̶d̶ ̶C̶h̶u̶r̶n̶ ̶a̶r̶e̶ ̶t̶h̶e̶ ̶s̶a̶m̶e̶
# ̶
# ________________________________________________________
#
#
# The monthly_charges distributions of the Non_Churn to Churn
#     Has a U-stat of 1329303.0 and p-value aprox. 0.00%
#
#            We can REJECT the Hₒ:
# H̶ₒ̶:̶ ̶T̶h̶e̶ ̶m̶o̶n̶t̶h̶l̶y̶_̶c̶h̶a̶r̶g̶e̶s̶ ̶D̶i̶s̶t̶r̶i̶b̶u̶t̶i̶o̶n̶s̶ ̶o̶f̶ ̶N̶o̶n̶_̶C̶h̶u̶r̶n̶ ̶a̶n̶d̶ ̶C̶h̶u̶r̶n̶ ̶a̶r̶e̶ ̶t̶h̶e̶ ̶s̶a̶m̶e̶
# ̶
# ________________________________________________________
#
#
# The total_charges distributions of the Non_Churn to Churn
#     Has a U-stat of 2254592.0 and p-value aprox. 0.00%
#
#            We can REJECT the Hₒ:
# ...

# %% [markdown]
# ##  WOW.... well I think we can put that hypothesis to rest!

# %%
sns.pairplot(data = train,
             x_vars=num_vars, 
             y_vars=num_vars, 
             hue='churn_Yes',
             corner=True
            )
plt.show()

# %% [markdown]
# #####  * Explore your `telco` data to discover drivers of churn

# %%
train.senior_citizen[train.churn_Yes == 0].value_counts()
# Out:
# 0    2697
# 1     407
# Name: senior_citizen, dtype: int64

# %%
train.senior_citizen[train.churn_Yes == 1].value_counts()
# Out:
# 0    844
# 1    277
# Name: senior_citizen, dtype: int64

# %% [markdown]
# ## None of this mean anything until we get rid of the can't churns...

# %%
df= acquire.get_telco_data()

# %%
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines internet_service_type online_security  \
# ...

# %%
df = df.drop(columns=['customer_id', 'gender'])

# %%
df
# Out:
#       senior_citizen partner dependents  tenure phone_service  \
# 0                  0     Yes        Yes       9           Yes
# 1                  0      No         No       9           Yes
# 2                  0      No         No       4           Yes
# 3                  1     Yes         No      13           Yes
# 4                  1     Yes         No       3           Yes
# ...              ...     ...        ...     ...           ...
# 7038               0      No         No      13           Yes
# 7039               0     Yes         No      22           Yes
# 7040               0      No         No       2           Yes
# 7041               0     Yes        Yes      67           Yes
# 7042               0     Yes        Yes      63            No
#
#         multiple_lines internet_service_type online_security online_backup  \
# 0                   No                   DSL              No           Yes
# ...

# %%
df1= acquire.get_telco_data()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   senior_citizen         7043 non-null   int64
#  1   partner                7043 non-null   object
#  2   dependents             7043 non-null   object
#  3   tenure                 7043 non-null   int64
#  4   phone_service          7043 non-null   object
#  5   multiple_lines         7043 non-null   object
#  6   internet_service_type  7043 non-null   object
#  7   online_security        7043 non-null   object
#  8   online_backup          7043 non-null   object
#  9   device_protection      7043 non-null   object
#  10  tech_support           7043 non-null   object
#  11  streaming_tv           7043 non-null   object
#  12  streaming_movies       7043 non-null   object
#  13  contract_type          7043 non-null   object
# ...

# %%
df1.contract_type.unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
df1.tenure.unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14, 35,
#        64, 39, 40, 11,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 31, 36, 17,
#        18, 51, 38, 42,  0])

# %%
no_opp = df1[(df1.contract_type == 'One year') & (df.tenure <= 13)]

# %%
len(no_opp)
# Out:
# 139

# %%
no_opp.churn[no_opp.churn == 1]
# Out:
# Series([], Name: churn, dtype: object)

# %%
no_opp2 = df1[(df1.contract_type == 'Two year')& (df.tenure <= 25)]

# %%
len(no_opp2)
# Out:
# 167

# %%
no_opp2.churn[no_opp2.churn == 1]
# Out:
# Series([], Name: churn, dtype: object)

# %%
df1.drop(no_opp.index)\
.drop(no_opp2.index)\
.drop(columns=['gender', 'customer_id'])
# Out:
#       senior_citizen partner dependents  tenure phone_service  \
# 1                  0      No         No       9           Yes
# 2                  0      No         No       4           Yes
# 3                  1     Yes         No      13           Yes
# 4                  1     Yes         No       3           Yes
# 5                  0      No        Yes       9           Yes
# ...              ...     ...        ...     ...           ...
# 7037               0      No         No       4           Yes
# 7039               0     Yes         No      22           Yes
# 7040               0      No         No       2           Yes
# 7041               0     Yes        Yes      67           Yes
# 7042               0     Yes        Yes      63            No
#
#         multiple_lines internet_service_type      online_security  \
# 1                  Yes                   DSL                   No
# 2                   No           Fiber optic                   No
# ...

# %%
Drop ['gender', 'partner', 'multiple_lines', '']

# %%
# Time to break the bank

def prep_telco():
    df = acquire.get_telco_data()

    encode = ['dependents', 'phone_service', 'internet_service_type', 
             'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
             'contract_type', 'paperless_billing', 'payment_type', 'churn']

    df['null_charges'] = pd.to_numeric(df['total_charges'], errors='coerce').isnull()

    df['total_charges'][df['null_charges']== True] = df['monthly_charges'][df['null_charges']== True]

    df.total_charges = df.total_charges.astype(float)

    df.drop(columns= 'null_charges', inplace=True)

    dummy_df = pd.get_dummies(df[encode], drop_first=True)

    df = pd.concat([df, dummy_df], axis=1)

    df = df.drop(columns=encode)
    print(df.info())
    return df

# %% [markdown]
# #####  * Determine if certain columns should be dropped

# %%
def iHμ(x=7,y=50):
    print(f"Let's see the Iterative Harmonic Mean of {x}, and {y}")
    
    while (x+y)/2 != x:
        harm = 2/(1/x + 1/y)
        mean = (x+y)/2
        x= harm
        y= mean
        print(x,y)
    print(f'The iterative Harmonic μ: {x}')

# %%
iHμ(.01456,.03435)
# Out:
# Let's see the Iterative Harmonic Mean of 0.01456, and 0.03435
# 0.020451277857288896 0.024454999999999998
# 0.022274658415886547 0.022453138928644447
# 0.022363542570519767 0.022363898672265497
# 0.02236372061997506 0.022363720621392632
# 0.022363720620683845 0.022363720620683848
# 0.022363720620683848 0.022363720620683848
# The iterative Harmonic μ: 0.022363720620683848

# %%
from fractions import Fraction

# %%
x
# Out:
# 31.622776601683796

# %%
Fraction(x).limit_denominator()
# Out:
# Fraction(24587531, 777526)

# %%
z= x-14

for i in range(1000):
    print(i, z*i)
# Out:
# 0 0.0
# 1 0.142135623730951
# 2 0.284271247461902
# 3 0.42640687119285303
# 4 0.568542494923804
# 5 0.710678118654755
# 6 0.8528137423857061
# 7 0.9949493661166571
# 8 1.137084989847608
# 9 1.279220613578559
# 10 1.42135623730951
# 11 1.5634918610404611
# 12 1.7056274847714121
# 13 1.8477631085023631
# 14 1.9898987322333141
# 15 2.132034355964265
# 16 2.274169979695216
# 17 2.416305603426167
# 18 2.558441227157118
# 19 2.700576850888069
# 20 2.84271247461902
# 21 2.9848480983499712
# 22 3.1269837220809222
# 23 3.2691193458118732
# 24 3.4112549695428243
# 25 3.5533905932737753
# 26 3.6955262170047263
# 27 3.8376618407356773
# 28 3.9797974644666283
# 29 4.121933088197579
# 30 4.26406871192853
# 31 4.406204335659481
# 32 4.548339959390432
# 33 4.690475583121383
# 34 4.832611206852334
# 35 4.974746830583285
# 36 5.116882454314236
# 37 5.259018078045187
# 38 5.401153701776138
# 39 5.543289325507089
# 40 5.68542494923804
# 41 5.827560572968991
# 42 5.9696961966999424
# ...

# %% [markdown]
# #####  * Determine if it would be valuable to bin some numeric columns

# %% [markdown]
# #####  * Determine if it would be valuable to combine multiple columns into one.

# %% [markdown]
# #####  * What are your drivers of churn?

# %% [markdown]
# #####  * Does it make sense to combine any features?

# %% [markdown]
# #####  * Do you find any surprises?

# %% [markdown]
# #####  * Document any and all findings and takeaways in your notebook using markdown.
